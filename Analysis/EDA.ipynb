# %% [markdown]
# # Exploratory Data Analysis

# %%
# Import libraries
import pandas as pd

# Load data
completed_df = pd.read_csv('../data/processed/completed_data.csv')

# %% [markdown]
# ## Basic Data information

# %%
print('Cleaned dataset for 2023, number of rows and columns: ')
print(completed_df.shape)
print('')

print(completed_df.info(verbose=True))
# Out:
# Cleaned dataset for 2023, number of rows and columns:
# (3751, 20)
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3751 entries, 0 to 3750
# Data columns (total 20 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Facility ID                   3751 non-null   object
#  1   Facility Name                 3751 non-null   object
#  2   City/Town                     3751 non-null   object
#  3   State                         3751 non-null   object
#  4   Number of Completed Surveys   3751 non-null   int64
#  5   Survey Response Rate Percent  3751 non-null   int64
#  6   Year                          3751 non-null   int64
#  7   Nurse Communication           3751 non-null   int64
#  8   Doctor Communication          3751 non-null   int64
#  9   Staff Responsiveness          3751 non-null   int64
#  10  Medicine Communication        3751 non-null   int64
#  11  Discharge Information         3751 non-null   int64
#  12  Care Transition               3751 non-null   int64
#  13  Cleanliness                   3751 non-null   int64
#  14  Quietness                     3751 non-null   int64
#  15  Rating Score                  3751 non-null   int64
#  16  Recommendation                3751 non-null   int64
#  17  State Name                    3751 non-null   object
#  18  Region                        3751 non-null   object
#  19  Division                      3751 non-null   object
# dtypes: int64(13), object(7)
# memory usage: 586.2+ KB
# None

# %% [markdown]
# ## Information by Region

# %%
# Get Statistics by Region
byRegion_df = completed_df.groupby('Region').agg({
    'Number of Completed Surveys': 'mean',
    'Survey Response Rate Percent': 'mean',
    'Facility ID': 'count',
    'Nurse Communication': 'mean',
    'Doctor Communication': 'mean',
    'Staff Responsiveness': 'mean',
    'Medicine Communication': 'mean',
    'Discharge Information': 'mean',
    'Care Transition': 'mean',
    'Cleanliness': 'mean',
    'Quietness': 'mean',
    'Rating Score': 'mean',
    'Recommendation': 'mean'
}).reset_index().rename(columns={
    'Number of Completed Surveys': 'Avg Completed Surveys',
    'Survey Response Rate Percent': 'Avg Response Rate',
    'Facility ID': 'Facilities Count'
}).round(2)

# Calculate total statistics
total_stats = byRegion_df.agg({
    'Avg Completed Surveys': 'mean',
    'Avg Response Rate': 'mean',
    'Facilities Count': 'sum',
    'Nurse Communication': 'mean',
    'Doctor Communication': 'mean',
    'Staff Responsiveness': 'mean',
    'Medicine Communication': 'mean',
    'Discharge Information': 'mean',
    'Care Transition': 'mean',
    'Cleanliness': 'mean',
    'Quietness': 'mean',
    'Rating Score': 'mean',
    'Recommendation': 'mean'
}).to_frame().transpose().round(2)

# Sort the DataFrame by 'Facilities Count' in descending order
byRegion_df = byRegion_df.sort_values(by='Rating Score', ascending=False)

# Add a 'Region' entry for the total statistics
total_stats['Region'] = 'Total'

# Concatenate region_stats and total_stats
byRegion_df = pd.concat([byRegion_df, total_stats], ignore_index=True)

# Set index
if 'Region' in byRegion_df.columns:
    byRegion_df.set_index('Region', inplace=True)

# Print the statistics by region and total
print('Statistics by Region and Total: ')
byRegion_df
# Out:
# Statistics by Region and Total:
#                   Avg Completed Surveys  Avg Response Rate  Facilities Count  \
# Region
# Midwest                          525.99              28.10            1056.0
# South                            645.00              20.79            1399.0
# West                             601.71              21.32             766.0
# Northeast                        719.68              24.16             517.0
# U.S. Territories                 421.38              27.46              13.0
# Total                            582.75              24.37            3751.0
#
#                   Nurse Communication  Doctor Communication  \
# Region
# Midwest                         91.87                 91.41
# South                           90.64                 90.77
# West                            89.90                 89.66
# Northeast                       90.19                 89.77
# U.S. Territories                84.46                 87.00
# Total                           89.41                 89.72
#
#                   Staff Responsiveness  Medicine Communication  \
# Region
# Midwest                          85.56                   77.94
# South                            83.11                   76.13
# West                             82.87                   75.96
# Northeast                        81.47                   74.45
# U.S. Territories                 74.77                   63.46
# Total                            81.56                   73.59
#
#                   Discharge Information  Care Transition  Cleanliness  \
# Region
# Midwest                           87.30            81.88        87.15
# South                             85.03            80.69        85.62
# West                              85.48            79.88        86.07
# Northeast                         85.55            79.72        85.02
# U.S. Territories                  69.69            75.46        84.00
# Total                             82.61            79.53        85.57
#
#                   Quietness  Rating Score  Recommendation
# Region
# Midwest               84.12         88.40           87.71
# South                 84.24         87.16           86.16
# West                  79.47         86.78           86.02
# Northeast             78.03         85.85           84.92
# U.S. Territories      79.62         78.92           77.54
# Total                 81.10         85.42           84.47

# %%
# Remove the 'Total' row
byRegion_df = byRegion_df[byRegion_df.index != 'Total']

# Create CSV file
byRegion_df.to_csv('../data/processed/region_statistics.csv')

# %% [markdown]
# ## Information by Division

# %%
# Get Statistics by Division
byDivision_df = completed_df.groupby('Division').agg({
    'Number of Completed Surveys': 'mean',
    'Survey Response Rate Percent': 'mean',
    'Facility ID': 'count',
    'Nurse Communication': 'mean',
    'Doctor Communication': 'mean',
    'Staff Responsiveness': 'mean',
    'Medicine Communication': 'mean',
    'Discharge Information': 'mean',
    'Care Transition': 'mean',
    'Cleanliness': 'mean',
    'Quietness': 'mean',
    'Rating Score': 'mean',
    'Recommendation': 'mean'
}).reset_index().rename(columns={
    'Number of Completed Surveys': 'Avg Completed Surveys',
    'Survey Response Rate Percent': 'Avg Response Rate',
    'Facility ID': 'Facilities Count'
}).round(2)
# Sort by most facilities by state
byDivision_df = byDivision_df.sort_values(by='Facilities Count', ascending=False)

# Set index
if 'Division' in byDivision_df.columns:
    byDivision_df.set_index('Division', inplace=True)

# Print
print('Stats by Division: ')
byDivision_df
# Out:
# Stats by Division:
#                     Avg Completed Surveys  Avg Response Rate  \
# Division
# East North Central                 591.95              26.75
# South Atlantic                     763.31              20.46
# West South Central                 547.94              20.68
# Pacific                            688.35              20.29
# West North Central                 427.28              30.12
# Middle Atlantic                    767.35              23.97
# Mountain                           478.98              22.77
# East South Central                 563.61              21.66
# New England                        617.06              24.57
# U.S. Territories                   421.38              27.46
#
#                     Facilities Count  Nurse Communication  \
# Division
# East North Central               633                91.51
# South Atlantic                   609                89.88
# West South Central               495                91.31
# Pacific                          449                89.29
# West North Central               423                92.41
# Middle Atlantic                  353                89.75
# Mountain                         317                90.75
# East South Central               295                91.09
# New England                      164                91.13
# U.S. Territories                  13                84.46
#
#                     Doctor Communication  Staff Responsiveness  \
# Division
# East North Central                 90.79                 84.73
# South Atlantic                     89.84                 81.37
# West South Central                 91.33                 84.73
# Pacific                            89.05                 81.57
# West North Central                 92.33                 86.80
# Middle Atlantic                    89.34                 80.84
# Mountain                           90.51                 84.70
# East South Central                 91.73                 83.97
# New England                        90.70                 82.80
# U.S. Territories                   87.00                 74.77
#
#                     Medicine Communication  Discharge Information  \
# Division
# East North Central                   77.17                  87.26
# South Atlantic                       74.31                  84.49
# West South Central                   77.83                  85.53
# Pacific                              75.13                  84.96
# West North Central                   79.10                  87.36
# Middle Atlantic                      73.62                  84.67
# Mountain                             77.13                  86.21
# East South Central                   77.04                  85.33
# New England                          76.26                  87.46
# U.S. Territories                     63.46                  69.69
#
#                     Care Transition  Cleanliness  Quietness  Rating Score  \
# Division
# East North Central            81.42        86.67      83.09         87.88
# South Atlantic                79.76        84.44      81.96         86.15
# West South Central            81.63        87.24      86.39         88.32
# Pacific                       79.20        85.80      77.05         86.14
# West North Central            82.56        87.87      85.65         89.19
# Middle Atlantic               79.20        84.64      78.02         85.40
# Mountain                      80.84        86.45      82.89         87.70
# East South Central            81.02        85.32      85.35         87.29
# New England                   80.86        85.82      78.07         86.83
# U.S. Territories              75.46        84.00      79.62         78.92
#
#                     Recommendation
# Division
# East North Central           86.87
# South Atlantic               85.00
# West South Central           87.55
# Pacific                      85.27
# West North Central           88.96
# Middle Atlantic              84.14
# Mountain                     87.10
# East South Central           86.21
# New England                  86.58
# U.S. Territories             77.54

# %% [markdown]
# ## Information by State

# %%
# Get Statistics by state
byState_df = completed_df.groupby('State').agg({
    'Region':'first',
    'State Name':'first',
    #'State':'first',
    'Number of Completed Surveys': 'mean',
    'Survey Response Rate Percent': 'mean',
    'Facility ID': 'count',
    'Nurse Communication': 'mean',
    'Doctor Communication': 'mean',
    'Staff Responsiveness': 'mean',
    'Medicine Communication': 'mean',
    'Discharge Information': 'mean',
    'Care Transition': 'mean',
    'Cleanliness': 'mean',
    'Quietness': 'mean',
    'Rating Score': 'mean',
    'Recommendation': 'mean'
}).reset_index().rename(columns={
    'Number of Completed Surveys': 'Avg Completed Surveys',
    'Survey Response Rate Percent': 'Avg Response Rate',
    'Facility ID': 'Facilities Count'
}).round(2)
# Sort by most facilities by state
byState_df = byState_df.sort_values(by='Rating Score', ascending=False)


# Set index
if 'State' in byState_df.columns:
    byState_df.set_index('State', inplace=True)


# Print
print('Stats by States: ')
byState_df.head(5)
# Out:
# Stats by States:
#         Region    State Name  Avg Completed Surveys  Avg Response Rate  \
# State
# NE     Midwest      Nebraska                 415.31              32.75
# SD     Midwest  South Dakota                 307.48              33.69
# IA     Midwest          Iowa                 314.24              30.79
# KS     Midwest        Kansas                 457.48              31.04
# WI     Midwest     Wisconsin                 490.54              32.07
#
#        Facilities Count  Nurse Communication  Doctor Communication  \
# State
# NE                   51                93.08                 92.98
# SD                   29                92.97                 93.07
# IA                   78                92.88                 93.01
# KS                   67                92.15                 92.21
# WI                  119                93.02                 92.24
#
#        Staff Responsiveness  Medicine Communication  Discharge Information  \
# State
# NE                    87.67                   80.29                  88.12
# SD                    89.24                   82.14                  87.45
# IA                    86.95                   79.56                  88.45
# KS                    87.24                   79.39                  86.36
# WI                    87.50                   80.90                  89.37
#
#        Care Transition  Cleanliness  Quietness  Rating Score  Recommendation
# State
# NE               83.55        89.00      87.10         90.04           90.41
# SD               83.59        88.59      86.83         90.00           90.76
# IA               83.06        89.44      85.73         89.81           89.90
# KS               82.48        88.93      86.57         89.67           89.13
# WI               83.27        89.18      85.74         89.62           89.11

# %%
# Create CSV file
byState_df.to_csv('../data/processed/state_statistics.csv')
